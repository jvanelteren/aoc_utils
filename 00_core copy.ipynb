# %%
# default_exp aoc_second
from aocutils.aoc import *

# %% [markdown]
# # AOC
#
# > This is a test

# %%
#hide
from nbdev.showdoc import *

# %%
#export
class Test():
    def __init__(self):
        self.a = 1

# %%
t = Test()
assert t.a == 1
